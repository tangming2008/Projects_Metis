# %% [markdown]
# ### Import packages

# %%
# %run '1_import_packages_functions.ipynb'

# %% [markdown]
# ### Validate with separate test dataset

# %%
model_path_1 = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/model_2-labels_clear-1000_blurry-1000/my_model_1204_1000_clear_1000_blurry.h5'
model_path_2 = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/model_2-labels_clear-1000_blurry-1000/my_model_1201_1.h5'
model_path_3 ='/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/model_1207_5-labels_clear-1000_out-of-focus-700_gaussian-1000_motion-1000_minifilter-1000_epochs-5/model_1207_5-labels_clear-1000_out-of-focus-700_gaussian-1000_motion-1000_minifilter-1000_epochs-5.h5'

model = load_model(model_path_3)

# %%
# We shall use the predefined function of 'predict_folder_image_test' here

#  folder_path_test = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/datasets/0_All/test_cat'
folder_path_dog = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/datasets/0_All/test_dog'
folder_path_clear = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/datasets/0_All/0_clear_4195'
folder_path_blurry = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/datasets/0_All/1_blurry_4331'
folder_path_cat_camera = '/Users/MingTang/Documents/Data_Science/00_Project/00_Image_CNN/datasets/0_All/cat_camera'

folder_path_test = folder_path_dog

# predict_folder_image(folder_path_test, 6)

for i in range(20):
    # image_index = 10
    predict_folder_image(model, folder_path_test, i)
# Out:
# Folder:  test_dog
# 'This is DS_Store file'
# Folder:  test_dog
# [2] [[  1.27449021e-04   2.61772540e-03   9.85142887e-01   1.18260272e-02
#     2.85983318e-04]]
# <PIL.Image.Image image mode=RGB size=200x200 at 0x121DF25F8>
# Folder:  test_dog
# [1] [[  3.12461704e-03   9.53153551e-01   5.08514995e-06   2.94790450e-08
#     4.37167734e-02]]
# <PIL.Image.Image image mode=RGB size=200x200 at 0x124DDF0F0>
# Folder:  test_dog
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-37-89484a0cb2bd> in <module>()
#      13 for i in range(20):
#      14     # image_index = 10
# ---> 15     predict_folder_image(model, folder_path_test, i)
#
# <ipython-input-31-78bfb10a09fc> in predict_folder_image(model, folder_path, image_index)
#      13     if file_name != '.DS_Store':
#      14         image_path = folder_path + '/' + file_name
# ...
